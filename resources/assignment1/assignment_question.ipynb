# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
a=input("thype any thing:")
print("you typed:",a)
# Out:
# you typed: ABCD

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num=int(input("Enter a number:"))
if num>0:
    print("Positive")
elif num<0:
    print("Negative")
else:
    print("Zero")
# Out:
# Zero

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
num3=int(input("Enter third number:"))
if num1>=num2 and num1>=num3:
    print("Largest number is:",num1)
elif num2>=num1 and num2>=num3:
    print("Largest number is:",num2)
else:
    print("Largest number is:",num3)
# Out:
# Largest number is: 75

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
num=int(input("Enter a number:"))
fac=num
for i in range(num-1,0,-1):
    fac=i*fac
print("Factorial is:",fac)
# Out:
# Factorial is: 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
integer=56
print(integer,type(integer))
float=56.78
print(float,type(float))
string="Hello"
print(string,type(string))
boolean=True
print(boolean,type(boolean))
# Out:
# 56 <class 'int'>
# 56.78 <class 'float'>
# Hello <class 'str'>
# True <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a=35
b=12
c=a
a=b
b=c
print("After swapping: a =",a,"b =",b)
# Out:
# After swapping: a = 12 b = 35

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
cal=int(input("Enter temperature in calsius:"))
fah=(cal*9/5)+32
print("Temperature in Fahrenheit is:",fah)
# Out:
# Temperature in Fahrenheit is: 194.0

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
st1=input("Enter first string:")
st2=input("Enter second string:")
print("Concatenated string is:",st1+st2)
# Out:
# Concatenated string is: hello World

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
var1=10
var2="String"
var3=45.67
var4=False
if type(var1)==int:
    print("var1 is of type Integer")
if type(var2)==str:
    print("var2 is of type String")
if type(var3)==float:
    print("var3 is of type Float")
if type(var4)==bool:
    print("var4 is of type Boolean")
# Out:
# var1 is of type Integer
# var2 is of type String
# var4 is of type Boolean

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
print("sum is:",num1+num2)
print("difference is:",num1-num2)
print("product is:",num1*num2)
print("quotient is:",num1/num2)
print("modulus is:",num1%num2)
print("exponentiation is:",num1**num2)
print("floor division is:",num1//num2)
# Out:
# sum is: 9
# difference is: 3
# product is: 18
# quotient is: 2.0
# modulus is: 0
# exponentiation is: 216
# floor division is: 2

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
num1=int(input("Enter first number:"))
num2=int(input("Enter second number:"))
if num1>num2:
    print(num1,"is greater than",num2)
if num1<num2:
    print(num1,"is less than",num2)
if num1==num2:
    print(num1,"is equal to",num2)
if num1>=num2:
    print(num1,"is greater than or equal to",num2)
if num1<=num2:
    print(num1,"is less than or equal to",num2)
# Out:
# 65 is equal to 65
# 65 is greater than or equal to 65
# 65 is less than or equal to 65

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
if 8>2 and 5<10:
    print("Both conditions are True")
if 8>10 or 5<10:
    print("At least one condition is True")
if not(8<5):
    print("Condition is True because 8 is not less than 5")
# Out:
# Both conditions are True
# At least one condition is True
# Condition is True because 8 is not less than 5

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
num=int(input("Enter a number:"))
print(num**2)
# Out:
# 2025

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num=int(input("Enter a number:"))
if num%2==0:
    print(num,"is even")
else:
    print(num,"is odd")
# Out:
# 23 is odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
num=int(input("Enter a number:"))
sum=0
for i in range(1,num+1):
    sum=i+sum
print("Sum of first",num,"natural numbers is:",sum)
# Out:
# Sum of first 15 natural numbers is: 120

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
num=int(input("Enter a number:"))
if num%4==0 and num%100!=0 :
    print(num,"is a leap year")
else:
    print(num,"is not a leap year")
# Out:
# 2000 is not a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str=input("Enter a string:")
str_rev=str[::-1]
print("Reversed string is:",str_rev)
# Out:
# Reversed string is: rahkarP

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
Str=input("Enter a string:")
str_rev=Str[::-1]
if Str==str_rev:
    print(Str,"is a palindrome")
else:
    print(Str,"is not a palindrome")
# Out:
# roor is a palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
random_list=[12,45,23,67,34,89,10,5]
print("Original list:",random_list)
random_list.sort()
print("Sorted list:",random_list)
# Out:
# Original list: [12, 45, 23, 67, 34, 89, 10, 5]
# Sorted list: [5, 10, 12, 23, 34, 45, 67, 89]
