# %%
current_value=1
for i in  range(1,366):
    print(f"day {i}: we recive {current_value} Rs")
    current_value*=2
# Out:
# day 1: we recive 1 Rs
# day 2: we recive 2 Rs
# day 3: we recive 4 Rs
# day 4: we recive 8 Rs
# day 5: we recive 16 Rs
# day 6: we recive 32 Rs
# day 7: we recive 64 Rs
# day 8: we recive 128 Rs
# day 9: we recive 256 Rs
# day 10: we recive 512 Rs
# day 11: we recive 1024 Rs
# day 12: we recive 2048 Rs
# day 13: we recive 4096 Rs
# day 14: we recive 8192 Rs
# day 15: we recive 16384 Rs
# day 16: we recive 32768 Rs
# day 17: we recive 65536 Rs
# day 18: we recive 131072 Rs
# day 19: we recive 262144 Rs
# day 20: we recive 524288 Rs
# day 21: we recive 1048576 Rs
# day 22: we recive 2097152 Rs
# day 23: we recive 4194304 Rs
# day 24: we recive 8388608 Rs
# day 25: we recive 16777216 Rs
# day 26: we recive 33554432 Rs
# day 27: we recive 67108864 Rs
# day 28: we recive 134217728 Rs
# day 29: we recive 268435456 Rs
# day 30: we recive 536870912 Rs
# day 31: we recive 1073741824 Rs
# day 32: we recive 2147483648 Rs
# day 33: we recive 4294967296 Rs
# day 34: we recive 8589934592 Rs
# ...
